# %%
import os
import matplotlib.pyplot as plt
import numpy as np
#import tensorflow as tf


# import required libraries
import cv2
import os

# %%
count = 0
dirx = "C:/Users/research/Desktop/thesis/test/aaz"
ndir = "C:/Users/research/Desktop/thesis/test/aaza"
for files in os.listdir(dirx):
    count = count + 1
    print(count)
    ndirx = dirx + '/' + files
    nmane = ndir + '/' + files
    #print(ndirx)
    # read the input image
    img = cv2.imread(ndirx)
    # convert to grayscale of each frames
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # read the haarcascade to detect the faces in an image
    face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

    # detects faces in the input image
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    print('Number of detected faces:', len(faces))
    
    if len(faces) == 0:
        # read the haarcascade to detect the faces in an image
        face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt2.xml')
        # detects faces in the input image
        faces = face_cascade.detectMultiScale(gray, 1.1, 2)
        print('Number of detected faces:', len(faces))
    
    if len(faces) == 0:
        # read the haarcascade to detect the faces in an image
        face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
        # detects faces in the input image
        faces = face_cascade.detectMultiScale(gray, 1.3, 4)
        print('Number of detected faces:', len(faces))
        
    if len(faces) == 0:
        # read the haarcascade to detect the faces in an image
        face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_profileface.xml')
        # detects faces in the input image
        faces = face_cascade.detectMultiScale(gray, 1.1, 2)
        print('Number of detected faces:', len(faces))
    if len(faces) > 0:
        for i, (x, y, w, h) in enumerate(faces):
            # To draw a rectangle in a face
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
            face = img[y:y + h, x:x + w]
            #cv2.imshow("Cropped Face", face)
            face = cv2.resize(face, (224, 224))
            cv2.imwrite(f'{nmane}', face)
            print(f"{nmane} is saved")
# Out:
# 1
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/ffhq_0.png is saved
# 2
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/ffhq_121.png is saved
# 3
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/ffhq_14.png is saved
# 4
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/ffhq_18.png is saved
# 5
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/ffhq_23.png is saved
# 6
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/ffhq_3.png is saved
# 7
# Number of detected faces: 0
# Number of detected faces: 0
# Number of detected faces: 0
# Number of detected faces: 0
# 8
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0000068.jpg is saved
# 9
# Number of detected faces: 0
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0000213.jpg is saved
# 10
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0000965.jpg is saved
# 11
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0001434.jpg is saved
# 12
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0001934.jpg is saved
# 13
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0001974.jpg is saved
# 14
# Number of detected faces: 2
# C:/Users/research/Desktop/thesis/test/aaza/image0002061.jpg is saved
# C:/Users/research/Desktop/thesis/test/aaza/image0002061.jpg is saved
# 15
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0002832.jpg is saved
# 16
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0002849.jpg is saved
# 17
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0003201.jpg is saved
# 18
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/image0009996.jpg is saved
# 19
# Number of detected faces: 0
# Number of detected faces: 0
# Number of detected faces: 0
# Number of detected faces: 0
# 20
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/Screenshot_20221101-073819_Opera Mini.jpg is saved
# 21
# Number of detected faces: 0
# Number of detected faces: 0
# Number of detected faces: 0
# Number of detected faces: 0
# 22
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/woman-suffering-stress-headache-grimacing-260nw-192268697.jpg is saved
# 23
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/young-african-american-man-holding-260nw-1820939108.jpg is saved
# 24
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/young-fit-sporty-woman-painful-260nw-1019069947.jpg is saved
# 25
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/young-funny-handsome-man-beard-260nw-1184217358.jpg is saved
# 26
# Number of detected faces: 1
# C:/Users/research/Desktop/thesis/test/aaza/young-girl-keeps-hand-on-260nw-571576168.jpg is saved

# %%
#testing image read the input image
img = cv2.imread("test/young-girl-keeps-hand-on-260nw-571576168.jpg")
#img = cv2.imread("JuVIA.png")
plt.imshow(img)

# convert to grayscale of each frames
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# read the haarcascade to detect the faces in an image
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# detects faces in the input image
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
print('Number of detected faces:', len(faces))

if len(faces) == 0:
    # read the haarcascade to detect the faces in an image
    face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt2.xml')
    # detects faces in the input image
    faces = face_cascade.detectMultiScale(gray, 1.1, 2)
    print('Number of detected faces:', len(faces))
    
if len(faces) == 0:
    # read the haarcascade to detect the faces in an image
    face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
    # detects faces in the input image
    faces = face_cascade.detectMultiScale(gray, 1.3, 4)
    print('Number of detected faces:', len(faces))
    
if len(faces) == 0:
    # read the haarcascade to detect the faces in an image
    face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_profileface.xml')
    # detects faces in the input image
    faces = face_cascade.detectMultiScale(gray, 1.1, 2)
    print('Number of detected faces:', len(faces))
    
    
if len(faces) > 0:
    for i, (x, y, w, h) in enumerate(faces):
        # To draw a rectangle in a face
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
        face = img[y:y + h, x:x + w]
        #cv2.imshow("Cropped Face", face)
        cv2.imwrite(f'face{i}.jpg', face)
        print(f"face{i}.jpg is saved")

# %%
count = 0
dirx = "C:/Users/research/Desktop/z8"
ndir = "C:/Users/research/Desktop/8"
for files in os.listdir(dirx):
    count = count + 1
    print(count)
    ndirx = dirx + '/' + files
    nmane = ndir + '/' + files
    #print(ndirx)
    # read the input image
    img = cv2.imread(ndirx)
    # convert to grayscale of each frames
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # read the haarcascade to detect the faces in an image
    #face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

    # detects faces in the input image
    #faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    #print('Number of detected faces:', len(faces))
    if 1 > 0:
        face = cv2.resize(img, (224, 224))
        
        #cv2.imshow("Cropped Face", face)
        ###nmane = nmane.replace("612x612", "612x612a")
        cv2.imwrite(f'{nmane}', face)
        print(f"{nmane} is saved")

# %%
 
# display the image with detected faces
#cv2.imshow("image", img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
count = 0
dirx = "aa"
ndir = "zppimgs"
for files in os.listdir(dirx):
    count = count + 1
    print(count)
    ndirx = dirx + '/' + files
    nmane = ndir + '/' + files
    #print(ndirx)
    # read the input image
    img = cv2.imread(ndirx)
    # convert to grayscale of each frames
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # read the haarcascade to detect the faces in an image
    face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

    # detects faces in the input image
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    print('Number of detected faces:', len(faces))
    
    if len(faces) == 0:
        # read the haarcascade to detect the faces in an image
        face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt2.xml')
        # detects faces in the input image
        faces = face_cascade.detectMultiScale(gray, 1.1, 2)
        print('Number of detected faces:', len(faces))
    
    if len(faces) == 0:
        # read the haarcascade to detect the faces in an image
        face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
        # detects faces in the input image
        faces = face_cascade.detectMultiScale(gray, 1.3, 4)
        print('Number of detected faces:', len(faces))
        
    if len(faces) == 0:
        # read the haarcascade to detect the faces in an image
        face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_profileface.xml')
        # detects faces in the input image
        faces = face_cascade.detectMultiScale(gray, 1.1, 2)
        print('Number of detected faces:', len(faces))
    if len(faces) > 0:
        rrcount = 1
        for i, (x, y, w, h) in enumerate(faces):
            # To draw a rectangle in a face
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
            face = img[y:y + h, x:x + w]
            #cv2.imshow("Cropped Face", face)
            new_jpg = str(rrcount) + ".jpg"
            new_nmane = nmane.replace(".jpg", new_jpg)
            cv2.imwrite(f'{new_nmane}', face)
            rrcount = rrcount + 1
            print(f"{new_nmane} is saved")

# %%
img1 = cv2.imread("C:/Users/research/Desktop/fer2013/test/surprise/PrivateTest_1338609.jpg")
plt.imshow(img1)

# %%
final_img = cv2.resize(img1, (224, 224))

# %%
final_img = np.expand_dims(final_img,axis =0) #adding fourth dimension

# %%
final_img = final_img/255.0 #normalizing

# %%
#import tensorflow as tf
#from tensorflow import keras
#from tensorflow.keras.models import load_model

# %%
new_modelp = load_model("my_apain_model_91ep.h5")

# %%
Predictions = new_modelp.predict(final_img)

# %%
Predictions[0]
# Out:
# array([3.3320218e-06, 3.0750861e-02, 1.5119085e-09, 6.9305330e-09,
#        9.6924579e-01, 4.1111601e-08], dtype=float32)

# %%
np.argmax(Predictions)
# Out:
# 0

# %%
print(Predictions)
# Out:
# [[9.7501421e-01 2.1020124e-02 1.6698646e-04 3.4313460e-04 3.3736068e-03
#   8.1952967e-05]]

# %%
from skimage import color
from skimage import io

import matplotlib.pyplot as plt
import numpy as np
#import tensorflow as tf
# import required libraries
import cv2
import os
from skimage import img_as_ubyte

# %%
#thesis2\training\0
count = 0
dirx = "C:/Users/research/Desktop/thesis2/test/0"
ndir = "C:/Users/research/Desktop/thesis2/test/0"
for files in os.listdir(dirx):
    count = count + 1
    print(count)
    ndirx = dirx + '/' + files
    nmane = ndir + '/' + files
    #print(ndirx)
    # read the input image
    img = io.imread(ndirx)
    imgGray = color.rgb2gray(img)
    io.imshow(imgGray)
    
    imgGray = cv2.resize(imgGray, (48, 48))
    io.imsave(nmane, img_as_ubyte(imgGray))
    
    #cv2.imwrite(f'{nmane}', imgGray)
    print(f"{nmane} is saved")
# Out:
# 1
# C:/Users/research/Desktop/thesis2/test/0/ffhq_1302.png is saved
# 2
# C:/Users/research/Desktop/thesis2/test/0/ffhq_1358.png is saved
# 3
# C:/Users/research/Desktop/thesis2/test/0/ffhq_1361.png is saved
# 4
# C:/Users/research/Desktop/thesis2/test/0/ffhq_2037.png is saved
# 5
# C:/Users/research/Desktop/thesis2/test/0/ffhq_2041.png is saved
# 6
# C:/Users/research/Desktop/thesis2/test/0/ffhq_2058.png is saved
# 7
# C:/Users/research/Desktop/thesis2/test/0/ffhq_256.png is saved
# 8
# C:/Users/research/Desktop/thesis2/test/0/ffhq_844.png is saved
# 9
# C:/Users/research/Desktop/thesis2/test/0/image0003810.jpg is saved
# 10
# C:/Users/research/Desktop/thesis2/test/0/image0004423.jpg is saved
# 11
# C:/Users/research/Desktop/thesis2/test/0/image0006923.jpg is saved
# 12
# C:/Users/research/Desktop/thesis2/test/0/image0006942.jpg is saved
# 13
# C:/Users/research/Desktop/thesis2/test/0/image0010927.jpg is saved
# 14
# C:/Users/research/Desktop/thesis2/test/0/image0011084.jpg is saved
# 15
# C:/Users/research/Desktop/thesis2/test/0/image0013393.jpg is saved
# 16
# C:/Users/research/Desktop/thesis2/test/0/image0016948.jpg is saved
# 17
# C:/Users/research/Desktop/thesis2/test/0/image0017397.jpg is saved
# 18
# C:/Users/research/Desktop/thesis2/test/0/image0017633.jpg is saved
# 19
# C:/Users/research/Desktop/thesis2/test/0/image0018290.jpg is saved
# 20
# C:/Users/research/Desktop/thesis2/test/0/image0018640.jpg is saved
# 21
# C:/Users/research/Desktop/thesis2/test/0/image0019462.jpg is saved
# 22
# C:/Users/research/Desktop/thesis2/test/0/image0020667.jpg is saved
# 23
# C:/Users/research/Desktop/thesis2/test/0/image0020800.jpg is saved
# 24
# C:/Users/research/Desktop/thesis2/test/0/image0020865.jpg is saved
# 25
# C:/Users/research/Desktop/thesis2/test/0/image0021030.jpg is saved
# 26
# C:/Users/research/Desktop/thesis2/test/0/image0021830.jpg is saved
# 27
# C:/Users/research/Desktop/thesis2/test/0/image0021879.jpg is saved
# 28
# C:/Users/research/Desktop/thesis2/test/0/image0022333.jpg is saved
# 29
# C:/Users/research/Desktop/thesis2/test/0/image0023251.jpg is saved
# 30
# C:/Users/research/Desktop/thesis2/test/0/image0023386.jpg is saved
# 31
# C:/Users/research/Desktop/thesis2/test/0/image0023414.jpg is saved
# 32
# C:/Users/research/Desktop/thesis2/test/0/image0023503.jpg is saved
